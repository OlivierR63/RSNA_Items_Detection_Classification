# %%
# 1. Clone application from the GitHub repository
# !git clone https://github.com/ton-compte/RSNA_Items_Detection_Classification.git

# 2. Launch the training script using Kaggle's data path
# !python src/RSNA_2024_Lumbar_Spine_Degenerative_Classification.py --data_dir="../input/rsna-2024-lumbar-spine-tfrecords"
